# %% [markdown]
# # Week 3 - Fitting a curve

# %% [markdown]
# ## section 1

# %%
# You may need this setup
using Plots
# pyplot()

# %% [markdown]
# - Create a new code cell below that will load the data into an array called data\_tofitdata_tofit. This array is already defined in the Week3_PR_Template.ipynb also in 'Week3_PR_Template.zip'. The additionally includes 'Week3_PR_Data.dat' that can be read in directly.

# %%
using DelimitedFiles
data_tofit = readdlm("Week3_PR_Data.dat")
# Out:
# 15×2 Array{Float64,2}:
#  0.1268     -1.6417
#  0.501309   -0.977698
#  1.52801     0.527711
#  1.70012     1.71152
#  1.99249     1.891
#  2.70608    -0.463428
#  2.99493    -0.443567
#  3.49185    -1.27518
#  3.50119    -0.6905
#  4.45992    -5.51613
#  4.93697    -6.0017
#  5.02329    -8.36417
#  5.04234    -7.92448
#  5.50739   -10.7748
#  5.56867   -10.9172

# %% [markdown]
# - Create a new code cell below. Write a ‘For’ loop to print out all the values of data\_tofitdata_tofit. The result should be numbers in 15 rows and two columns.

# %%
for i=1:size(data_tofit)[1]
    println(data_tofit[i,:])
end
# Out:
# [0.1268, -1.6417]
# [0.501309, -0.977698]
# [1.52801, 0.527711]
# [1.70012, 1.71152]
# [1.99249, 1.891]
# [2.70608, -0.463428]
# [2.99493, -0.443567]
# [3.49185, -1.27518]
# [3.50119, -0.6905]
# [4.45992, -5.51613]
# [4.93697, -6.0017]
# [5.02329, -8.36417]
# [5.04234, -7.92448]
# [5.50739, -10.7748]
# [5.56867, -10.9172]

# %% [markdown]
# - Create a new code cell below. Assign the values from the first column of data\_tofitdata_tofit into a new array called xx. Similarly assign the values from the second column of data\_tofitdata_tofit into a new array called yy.

# %%
x,y=data_tofit[:,1],data_tofit[:,2]
println(x)
println(y)
# Out:
# [0.1268, 0.501309, 1.52801, 1.70012, 1.99249, 2.70608, 2.99493, 3.49185, 3.50119, 4.45992, 4.93697, 5.02329, 5.04234, 5.50739, 5.56867]
# [-1.6417, -0.977698, 0.527711, 1.71152, 1.891, -0.463428, -0.443567, -1.27518, -0.6905, -5.51613, -6.0017, -8.36417, -7.92448, -10.7748, -10.9172]

# %% [markdown]
# - Create a new code cell below. Create a scatter plot with the x- and y-values on the x-axis and y-axis respectively.

# %%
plot(x,y,seriestype=:scatter)

# %% [markdown]
# - Create a new code cell below. Create a function called parabfit, with a single parameter xx , that returns the value of the expression $ax^2 + bx + c$ for a given x. The values for the variables a, b, and c will be defined next. Execute the code to create your function.

# %%
function parabfit(x)
    return a*x^2+b*x+c
end
# Out:
# parabfit (generic function with 1 method)

# %% [markdown]
# - Create a new code cell below. Assign the value 1 to the variables aa, bb, and cc respectively. Now create a plot of the curve defined by the parabfit function using: plot(parabfit, -5, 5)

# %%
a,b,c=1,1,1
plot(parabfit,-5,5)

# %% [markdown]
# ## section 2

# %% [markdown]
# - Create a new code cell. In this cell assign new values to aa, bb, and cc to fit the dat (hint: you can tell whether a is positive or negative, and you can guess at the value of c. In fact also b, which is the slope at x=0). Then copy the plot()plot() statement from above to display the scatter plot of the data and finally plot!()plot!() to overlay the function curve.

# %%
plot(x,y,seriestype=:scatter)
a=-1
b=-1
c=-1
plot!(parabfit,-5,5)

# %% [markdown]
# - Re-execute the above cell changing the values of aa, bb, and cc. By changing the sign or size of these variables can flip or shift the parabola’s position. Note that by looking at where the data points lie, we can deduce some of the properties for aa, bb, and cc, as follows. The plot must have a y-intersection that is close to 0, so cc is close to 0. Also, the parabola is open downwards, so aa must be negative. Finally, it has its maximum at a positive x, so bb must be positive. You will not need to consider values outside the range -4−4 and 44. It is often useful to include comments as your tried to identify reasonable fits (use # at the start). Each time regenerate the plot of the data and parabola. In the plots reduce the range for xx to positive values (e,g, 0 to 6) to more clearly view the fitted line. When you're happy with the fit, make sure you've given the diagram an informative title (you need not annotate the axes, as they are just numbers).

# %%
a=-1
b=-4a
c=-2.5
plot!(parabfit,-5,5)

# %% [markdown]
# - Create a new Markdown cell below. Add comments about reaching the parameters you chose. For example you might describe your process as follows: "Initially the values for a, b and c were not very good, a and b were too small, though c seemed good. Finally adjusting these further produced a parabola with a good approximation of the data.."

# %% [markdown]
# Initially the values for a, b and c were not very good, a and b were too small, though c seemed good. Finally adjusting these further produced a parabola with a good approximation of the data

# %% [markdown]
# ## example in source code

# %% [markdown]
# Import the supplied data representing 15 pairs to x- and y-values.

# %%
data_tofit = [1.6800483    -1.641695388; 
              0.501309281  -0.977697538; 
              1.528012113   0.52771122;
              1.70012253    1.711524991; 
              1.992493625   1.891000015;
              2.706075824  -0.463427794;
              2.994931927  -0.443566619;
              3.491852811  -1.275179133;
              3.501191722  -0.690499597;
              4.459924502  -5.516130799;
              4.936965851  -6.001703074;
              5.023289852  -8.36416901;
              5.04233698   -7.924477517;
              5.50739285  -10.77482371;
              5.568665171 -10.9171878]

# Create the arrays x and y, assigning x the first column of data_tofit and y the second column
# Out:
# 15×2 Array{Float64,2}:
#  1.68005    -1.6417
#  0.501309   -0.977698
#  1.52801     0.527711
#  1.70012     1.71152
#  1.99249     1.891
#  2.70608    -0.463428
#  2.99493    -0.443567
#  3.49185    -1.27518
#  3.50119    -0.6905
#  4.45992    -5.51613
#  4.93697    -6.0017
#  5.02329    -8.36417
#  5.04234    -7.92448
#  5.50739   -10.7748
#  5.56867   -10.9172

# %% [markdown]
# Then we do a scatterplot, this gives us the points the line must go through.

# %%
# Plot the x and y data points using a scatter plot of the x and y array variables

# %% [markdown]
# For the line, we need a function, which we now define. Note that the parameters a, b, c need not be passed to the function: we will keep resetting them to try to improve the fit.

# %%
# Create a function called parabfit, with x as the argument, returning a*x^2 + b*x + c

# %% [markdown]
# Let's check that we do get a reasonable parabola. Choose your own interval [xmin, xmax] and parameters a, b, c. If it looks too much like a straight line, chance your choices until it does.

# %%
# Create variables a, b and c, assigning each the value 1
a = 1
b = 1
c = 1

# Plot the function parabfit, for x values between -5 and 5
# Out:
# 1

# %% [markdown]
# Now we choose a, b, c and plot the curve together with the points.
#
# Note that by looking at where the data points lie, we can deduce some of the properties for a, b, c, as follows.
#
# The plot must have a y-intersection that is close to 0, so c is close to 0. Also, the parabola is open downwards, so a must be negative. Finally, it has its maximum at a positive x, so b must be positive.
#
# Use plot() to start with the scatter plot and plot!() to add the curve for parabfit. (There are other ways to do this ...)

# %%
# More plot!() tries.
# a,b,c =
